# %% [markdown]
# # Comparison of SciVal query works lists and OpenAlex general SFU works lists
# It appears that the OpenAlex queries are not fully encapsulating the works that are available in both SciVal and OpenAlex (it appears that works are not being fully attributed to SFU through the query search).
#
# Here we compare the full list of SFU authors to the SciVal queries to see how much overlap there is, and then we will merge this with the OpenAlex query pulls to see if the intersecting set is the same or different.

# %%
# import libraries 

import pandas as pd
import numpy as np
import json
import ast
import fuzzywuzzy
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from datetime import datetime
from tqdm import tqdm 
from collections import defaultdict
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
import requests

# q1
q1_oa_raw = pd.read_csv('../cerc_results/query1.csv')
q1_sv_raw = pd.read_excel('../cerc_results/query1_SCIVAL.xlsx', sheet_name="rio results")

# q2
q2_oa_raw = pd.read_csv('../cerc_results/query2.csv')
q2_sv_raw = pd.read_excel('../cerc_results/query2_SCIVAL.xlsx', sheet_name="rio results")

# q3
q3_oa_raw = pd.read_csv('../cerc_results/query3.csv')
q3_sv_raw = pd.read_excel('../cerc_results/query3_SCIVAL.xlsx', sheet_name="rio results")

# openalex all
oa_all_pubs = pd.read_csv('../sfu_all_works.csv')
oa_all_pubs['doi'] = oa_all_pubs['doi'].str.replace('https://doi.org/', '', regex=False).str.strip().str.lower()
# Out:
# C:\Users\tania\AppData\Local\Temp\ipykernel_8248\561244527.py:30: DtypeWarning: Columns (21,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   oa_all_pubs = pd.read_csv('../sfu_all_works.csv')

# %%
import ast

SFU_ID = 'I18014758'

def safe_parse(val):
    """Parse a stringified list/dict back to a Python object, or return as-is if already parsed."""
    if isinstance(val, (list, dict)):
        return val
    if isinstance(val, str):
        try:
            return ast.literal_eval(val)
        except (ValueError, SyntaxError):
            return []
    return []


def get_sfu_author_rankings(df: pd.DataFrame, sfu_id: str = SFU_ID) -> pd.DataFrame:

    records = []

    for _, row in df.iterrows():
        doi         = row.get('doi')
        authorships = safe_parse(row.get('authorships', []))
        citations   = row.get('cited_by_count', 0)

        if not isinstance(authorships, list):
            continue

        for authorship in authorships:
            if not isinstance(authorship, dict):
                continue

            institutions = safe_parse(authorship.get('institutions', []))
            is_sfu = any(
                (inst.get('id') or '').endswith(sfu_id)
                for inst in institutions
                if isinstance(inst, dict)
            )

            if not is_sfu:
                continue

            author      = authorship.get('author', {})
            author_id   = author.get('id', 'unknown')
            author_name = author.get('display_name', 'unknown')

            records.append({
                'author_id':   author_id,
                'author_name': author_name,
                'doi':         doi,
                'citations':   citations,
            })

    if not records:
        print('No SFU-affiliated authors found. Check that authorships column is parseable.')
        return pd.DataFrame()

    records_df = pd.DataFrame(records)

    rankings = (
        records_df
        .groupby(['author_id', 'author_name'], as_index=False)
        .agg(
            pub_count       =('doi',       'count'),
            total_citations =('citations', 'sum'),
            dois            =('doi',       lambda x: sorted(x.dropna().unique().tolist()))
        )
    )

    rankings['citation_rank'] = rankings['total_citations'].rank(method='min', ascending=False).astype(int)

    rankings = (
        rankings
        .sort_values('pub_count', ascending=False)
        .reset_index(drop=True)
    )

    rankings.index += 1
    rankings.index.name = 'pub_rank'

    rankings = rankings[['author_name', 'author_id', 'pub_count', 'total_citations', 'citation_rank', 'dois']]

    return rankings

# %%
SFU_SCOPUS_NAME = 'Simon Fraser University'

def get_sfu_author_rankings_scopus(
    df: pd.DataFrame,
    sfu_name: str = SFU_SCOPUS_NAME,
) -> pd.DataFrame:

    records = []

    for _, row in df.iterrows():
        doi               = row.get('DOI')
        author_full_names = row.get('Author full names', '')
        authors_with_affs = row.get('Authors with affiliations', '')
        author_ids_raw    = row.get('Author(s) ID', '')
        citations         = row.get('Cited by', 0)

        if not all(isinstance(x, str) for x in [author_full_names, authors_with_affs, author_ids_raw]):
            continue

        author_ids = [x.strip() for x in author_ids_raw.split(';') if x.strip()]

        name_id_pairs = []
        for entry in author_full_names.split(';'):
            entry = entry.strip()
            if not entry:
                continue
            if '(' in entry and ')' in entry:
                name    = entry[:entry.rfind('(')].strip()
                auth_id = entry[entry.rfind('(')+1 : entry.rfind(')')].strip()
            else:
                name    = entry.strip()
                idx     = len(name_id_pairs)
                auth_id = author_ids[idx] if idx < len(author_ids) else 'unknown'
            name_id_pairs.append((name, auth_id))

        name_to_id = {name: auth_id for name, auth_id in name_id_pairs}

        for entry in authors_with_affs.split(';'):
            entry = entry.strip()
            if not entry or sfu_name not in entry:
                continue

            parts = [p.strip() for p in entry.split(',')]
            if len(parts) < 2:
                continue

            author_name = f'{parts[0]}, {parts[1]}'
            author_id   = name_to_id.get(author_name, 'unknown')

            records.append({
                'author_id':   author_id,
                'author_name': author_name,
                'doi':         doi,
                'citations':   citations,
            })

    if not records:
        print('No SFU-affiliated authors found. Check that "Simon Fraser University" '
              'appears in the Authors with affiliations column.')
        return pd.DataFrame()

    records_df = pd.DataFrame(records)

    rankings = (
        records_df
        .groupby(['author_id', 'author_name'], as_index=False)
        .agg(
            pub_count       =('doi',       'count'),
            total_citations =('citations', 'sum'),
            dois            =('doi',       lambda x: sorted(x.dropna().unique().tolist()))
        )
    )

    rankings['citation_rank'] = rankings['total_citations'].rank(method='min', ascending=False).astype(int)

    rankings = (
        rankings
        .sort_values('pub_count', ascending=False)
        .reset_index(drop=True)
    )

    rankings.index += 1
    rankings.index.name = 'pub_rank'

    rankings = rankings[['author_name', 'author_id', 'pub_count', 'total_citations', 'citation_rank', 'dois']]
    
    return rankings

# %%
#oa_all_pubs

# %% [markdown]
# ## Query 1

# %%
q1_sv_raw.columns
# Out:
# Index(['Authors', 'Author full names', 'Author(s) ID', 'Title', 'Year',
#        'Source title', 'Volume', 'Issue', 'Art. No.', 'Page start', 'Page end',
#        'Cited by', 'DOI', 'Link', 'Affiliations', 'Authors with affiliations',
#        'Correspondence Address', 'Editors', 'Publisher', 'ISSN', 'ISBN',
#        'CODEN', 'PubMed ID', 'Language of Original Document',
#        'Abbreviated Source Title', 'Document Type', 'Publication Stage',
#        'Open Access', 'Source', 'EID'],
#       dtype='object')

# %%
q1_sv_clean = q1_sv_raw.copy()
q1_sv_clean = q1_sv_clean[['Title', 'DOI', 'Year', 'Cited by']]
q1_sv_clean
# Out:
#                                                  Title  \
# 0    Planck 2018 results: V. CMB power spectra and ...
# 1    SuperYOLO: Super Resolution Assisted Object De...
# 2    Sapien: A simulated part-based interactive ENv...
# 3    Habitat 2.0: Training Home Assistants to Rearr...
# 4    Flood detection and susceptibility mapping usi...
# ..                                                 ...
# 945  Logic-based space-vector modulation for neutra...
# 946  Handling coarsened age information in the anal...
# 947  Detection of Electric and Magnetic Dipole Mome...
# 948  Overcoming distrust: How state-owned enterpris...
# 949  Potential applications of multi-sensor remote ...
#
#                                     DOI  Year  Cited by
# 0           10.1051/0004-6361/201936386  2020       788
# 1             10.1109/TGRS.2023.3258666  2023       458
# 2          10.1109/CVPR42600.2020.01111  2020       377
# 3                                   NaN  2021       319
# 4                    10.3390/rs12020266  2020       317
# ..                                  ...   ...       ...
# 945           10.1049/iet-pel.2020.0594  2020         0
# 946          10.1186/s12874-020-01181-x  2020         0
# 947  10.1109/IEEECONF35879.2020.9330408  2020         0
# 948         10.4337/9781788978927.00023  2020         0
# 949                                 NaN  2020         0
#
# [950 rows x 4 columns]

# %%
q1_oa_clean = q1_oa_raw
q1_oa_clean['doi'] = q1_oa_clean['doi'].str.replace('https://doi.org/', '').str.lower()

q1_sv_doi_list = q1_sv_clean['DOI'].dropna().str.strip().str.lower()

q1_oa_works_in_sv = q1_oa_clean.copy()
q1_oa_works_in_sv = q1_oa_works_in_sv[q1_oa_works_in_sv['doi'].isin(q1_sv_doi_list)].reset_index().drop(columns=['index'])

print(len(q1_oa_works_in_sv))

q1_oa_merged = q1_oa_raw.copy()
q1_oa_merged['doi'] = q1_oa_merged['doi'].str.replace('https://doi.org/', '', regex=False).str.strip().str.lower()
q1_oa_merged = pd.concat([q1_oa_merged, q1_oa_works_in_sv]).drop_duplicates(subset='doi').reset_index(drop=True)

print(len(q1_oa_merged))

q1_comp = venn2(
    [set(q1_oa_merged['doi'].dropna()),
     set(q1_sv_clean['DOI'].dropna().str.strip().str.lower())],
    set_labels=('OpenAlex Q1', 'SciVal Q1')
)
# Out:
# 433
# 7253

# %% [markdown]
# omg

# %% [markdown]
# ## Query 2

# %%
q2_sv_raw.columns
# Out:
# Index(['Authors', 'Author full names', 'Author(s) ID', 'Title', 'Year',
#        'Source title', 'Volume', 'Issue', 'Art. No.', 'Page start', 'Page end',
#        'Cited by', 'DOI', 'Link', 'Affiliations', 'Authors with affiliations',
#        'Correspondence Address', 'Editors', 'Publisher', 'ISSN', 'ISBN',
#        'CODEN', 'PubMed ID', 'Language of Original Document',
#        'Abbreviated Source Title', 'Document Type', 'Publication Stage',
#        'Open Access', 'Source', 'EID'],
#       dtype='object')

# %%
q2_sv_clean = q2_sv_raw.copy()
q2_sv_clean = q2_sv_clean[['Title', 'DOI', 'Year', 'Cited by']]
q2_sv_clean
# Out:
#                                                  Title  \
# 0    Functional and versatile superhydrophobic coat...
# 1    Opioid agonist treatment and risk of mortality...
# 2       Optical observation of single spins in silicon
# 3    Dimensional diversity (0D, 1D, 2D, and 3D) in ...
# 4    A review of primary technologies of thin-film ...
# ..                                                 ...
# 324  ITERATIVE UNCERTAINTY CALIBRATION FOR MODELING...
# 325  Simulation of optical and mechanical performan...
# 326  Advanced modifications in nonnoble materials f...
# 327  Individual Nanoflakes of Two Dimensional Mater...
# 328  Characterizing the topology of kinetoplast DNA...
#
#                                     DOI  Year  Cited by
# 0            10.1038/s41467-021-21219-y  2021       279
# 1                      10.1136/bmj.m772  2020       170
# 2            10.1038/s41586-022-04821-y  2022       142
# 3                    10.1039/d3ta06953b  2024       122
# 4              10.1088/2631-8695/ac2353  2021       121
# ..                                  ...   ...       ...
# 324              10.1115/DETC2022-89511  2022         0
# 325      10.1109/PVSC43889.2021.9518957  2021         0
# 326  10.1016/B978-0-12-823708-3.00005-5  2021         0
# 327      10.1109/NMDC50713.2021.9677477  2021         0
# 328              10.1090/conm/746/15000  2020         0
#
# [329 rows x 4 columns]

# %%
q2_oa_clean = q2_oa_raw
q2_oa_clean['doi'] = q2_oa_clean['doi'].str.replace('https://doi.org/', '').str.lower()

q2_sv_doi_list = q2_sv_clean['DOI'].dropna().str.strip().str.lower()

q2_oa_works_in_sv = q2_oa_clean.copy()
q2_oa_works_in_sv = q2_oa_works_in_sv[q2_oa_works_in_sv['doi'].isin(q2_sv_doi_list)].reset_index().drop(columns=['index'])

print(len(q2_oa_works_in_sv))

q2_oa_merged = q2_oa_raw.copy()
q2_oa_merged['doi'] = q2_oa_merged['doi'].str.replace('https://doi.org/', '', regex=False).str.strip().str.lower()
q2_oa_merged = pd.concat([q2_oa_merged, q2_oa_works_in_sv]).drop_duplicates(subset='doi').reset_index(drop=True)

print(len(q2_oa_merged))

q2_comp = venn2(
    [set(q2_oa_merged['doi'].dropna()),
     set(q2_sv_clean['DOI'].dropna().str.strip().str.lower())],
    set_labels=('OpenAlex Q2', 'SciVal Q2'))
# Out:
# 253
# 1460

# %%
q2_sv_doi_list = q2_sv_clean['DOI'].dropna().str.strip().str.lower()

q2_oa_works_in_sv = oa_all_pubs.copy()
q2_oa_works_in_sv = q2_oa_works_in_sv[q2_oa_works_in_sv['doi'].isin(q2_sv_doi_list)].reset_index().drop(columns=['index'])

len(q2_oa_works_in_sv)
# Out:
# 295

# %%
q2_oa_merged = q2_oa_raw.copy()
q2_oa_merged['doi'] = q2_oa_merged['doi'].str.replace('https://doi.org/', '', regex=False).str.strip().str.lower()
q2_oa_merged = pd.concat([q2_oa_merged, q2_oa_works_in_sv]).drop_duplicates(subset='doi').reset_index(drop=True)

len(q2_oa_merged)
# Out:
# 1516

# %%
q2_comp = venn2(
    [set(q2_oa_merged['doi'].dropna()),
     set(q2_sv_clean['DOI'].dropna().str.strip().str.lower())],
    set_labels=('OpenAlex Q2', 'SciVal Q2')
)

# %% [markdown]
# ## Query 3

# %%
q3_sv_raw.columns
# Out:
# Index(['Authors', 'Author full names', 'Author(s) ID', 'Title', 'Year',
#        'Source title', 'Volume', 'Issue', 'Art. No.', 'Page start', 'Page end',
#        'Cited by', 'DOI', 'Link', 'Affiliations', 'Authors with affiliations',
#        'Correspondence Address', 'Editors', 'Publisher', 'ISSN', 'ISBN',
#        'CODEN', 'PubMed ID', 'Language of Original Document',
#        'Abbreviated Source Title', 'Document Type', 'Publication Stage',
#        'Open Access', 'Source', 'EID'],
#       dtype='object')

# %%
q3_sv_clean = q3_sv_raw.copy()
q3_sv_clean = q3_sv_clean[['Title', 'DOI', 'Year', 'Cited by']]
q3_sv_clean
# Out:
#                                                  Title  \
# 0    The Lancet Commission on lessons for the futur...
# 1    Human resource management in the age of genera...
# 2    Mobilizing Policy (In)Capacity to Fight COVID-...
# 3    How right-leaning media coverage of Covid-19 f...
# 4    The Knowns and Unknowns of Policy Instrument A...
# ..                                                 ...
# 763                     Russia’s Space Security Policy
# 764  Overcoming distrust: How state-owned enterpris...
# 765  Diplomatic and corporate networks: Bridges to ...
# 766  Lifetime trajectories of socio-economic advers...
# 767  Bridge Essay: Inalienable: Human Rights and Wo...
#
#                                   DOI  Year  Cited by
# 0       10.1016/S0140-6736(22)01585-9  2022       601
# 1             10.1111/1748-8583.12524  2023       600
# 2       10.1080/14494035.2020.1787628  2020       445
# 3           10.1017/S0008423920000396  2020       341
# 4            10.1177/2158244019900568  2020       297
# ..                                ...   ...       ...
# 763     10.1007/978-3-030-23210-8_128  2020         0
# 764       10.4337/9781788978927.00023  2020         0
# 765       10.4337/9781788978927.00024  2020         0
# 766  10.1332/175795919X15717233852148  2020         0
# 767    10.1002/9781118635193.ctwl0211  2020         0
#
# [768 rows x 4 columns]

# %%
q3_oa_clean = q3_oa_raw
q3_oa_clean['doi'] = q3_oa_clean['doi'].str.replace('https://doi.org/', '').str.lower()

q3_sv_doi_list = q3_sv_clean['DOI'].dropna().str.strip().str.lower()

q3_oa_works_in_sv = q3_oa_clean.copy()
q3_oa_works_in_sv = q3_oa_works_in_sv[q3_oa_works_in_sv['doi'].isin(q3_sv_doi_list)].reset_index().drop(columns=['index'])

print(len(q3_oa_works_in_sv))

q3_oa_merged = q3_oa_raw.copy()
q3_oa_merged['doi'] = q3_oa_merged['doi'].str.replace('https://doi.org/', '', regex=False).str.strip().str.lower()
q3_oa_merged = pd.concat([q3_oa_merged, q3_oa_works_in_sv]).drop_duplicates(subset='doi').reset_index(drop=True)

print(len(q3_oa_merged))

q3_comp = venn2(
    [set(q3_oa_merged['doi'].dropna()),
     set(q3_sv_clean['DOI'].dropna().str.strip().str.lower())],
    set_labels=('OpenAlex Q3', 'SciVal Q3'))
# Out:
# 554
# 2340

# %%
q3_sv_doi_list = q3_sv_clean['DOI'].dropna().str.strip().str.lower()

q3_oa_works_in_sv = oa_all_pubs.copy()
q3_oa_works_in_sv = q3_oa_works_in_sv[q3_oa_works_in_sv['doi'].isin(q3_sv_doi_list)].reset_index().drop(columns=['index'])

len(q3_oa_works_in_sv)
# Out:
# 634

# %%
q3_oa_merged = q3_oa_raw.copy()
q3_oa_merged['doi'] = q3_oa_merged['doi'].str.replace('https://doi.org/', '', regex=False).str.strip().str.lower()
q3_oa_merged = pd.concat([q3_oa_merged, q3_oa_works_in_sv]).drop_duplicates(subset='doi').reset_index(drop=True)

len(q3_oa_merged)
# Out:
# 2448

# %%
q3_comp = venn2(
    [set(q3_oa_merged['doi'].dropna()),
     set(q3_sv_clean['DOI'].dropna().str.strip().str.lower())],
    set_labels=('OpenAlex Q3', 'SciVal Q3')
)

# %% [markdown]
# as we suspected, the issue is that publications that are attributed to SFU authors in the general publication list are not being caught in the queries (i suspect it might be because of the cutoff)

# %% [markdown]
# ## check

# %%
max(q1_oa_raw['institutions_distinct_count'].unique())
# Out:
# np.int64(1431)

# %%
test = q1_oa_raw[q1_oa_raw['institutions_distinct_count'] == 1403]
test
# Out:
#                                     id                         doi  \
# 2580  https://openalex.org/W3005327280  10.1038/s41467-020-14352-7
#
#                                                   title  \
# 2580  Reconstructing evolutionary trajectories of mu...
#
#                                            display_name  relevance_score  \
# 2580  Reconstructing evolutionary trajectories of mu...         0.814143
#
#       publication_year publication_date  \
# 2580              2020       2020-02-05
#
#                                                     ids language  \
# 2580  {'openalex': 'https://openalex.org/W3005327280...       en
#
#                                        primary_location  ...  \
# 2580  {'id': 'doi:10.1038/s41467-020-14352-7', 'is_o...  ...
#
#                                                 funders  \
# 2580  [{'id': 'https://openalex.org/F4320309480', 'd...
#
#                             has_content  \
# 2580  {'pdf': True, 'grobid_xml': True}
#
#                                            content_urls  \
# 2580  {'pdf': 'https://content.openalex.org/works/W3...
#
#      referenced_works_count  \
# 2580                     50
#
#                                        referenced_works  \
# 2580  ['https://openalex.org/W1526705543', 'https://...
#
#                                           related_works  \
# 2580  ['https://openalex.org/W2146397496', 'https://...
#
#                                 abstract_inverted_index  \
# 2580  {'The': [0], 'type': [1, 98], 'and': [2, 94, 9...
#
#                                          counts_by_year  \
# 2580  [{'year': 2026, 'cited_by_count': 3}, {'year':...
#
#                     updated_date         created_date
# 2580  2026-06-25T08:15:23.626066  2025-10-10T00:00:00
#
# [1 rows x 50 columns]

# %%
print(test['institutions'])
# Out:
# 2580    []
# Name: institutions, dtype: object

# %%
test['display_name']
# Out:
# 2580    Reconstructing evolutionary trajectories of mu...
# Name: display_name, dtype: object

# %% [markdown]
# for some reason, all publications have an empty array in the institutions column. I need to try some more stuff

# %%
# initialize the API URL
# the cursor allows us to pull multiple pages of results to get all SFU works in one call. 
# NOTE: SFU's institutional id in OpenAlex is I18014f758

url = 'https://api.openalex.org/works/w3093734695'

result = requests.get(url)

#result.json()

# %%
test2 = pd.DataFrame([result.json()])
test2
# Out:
#                                  id  \
# 0  https://openalex.org/W3093734695
#
#                                                doi  \
# 0  https://doi.org/10.1140/epjc/s10052-021-09402-3
#
#                                                title  \
# 0  Jet energy scale and resolution measured in pr...
#
#                                         display_name  publication_year  \
# 0  Jet energy scale and resolution measured in pr...              2021
#
#   publication_date                                                ids  \
# 0       2021-08-01  {'openalex': 'https://openalex.org/W3093734695...
#
#   language                                   primary_location     type  ...  \
# 0       en  {'id': 'doi:10.1140/epjc/s10052-021-09402-3', ...  article  ...
#
#                                              funders  \
# 0  [{'id': 'https://openalex.org/F4320306076', 'd...
#
#                            has_content content_urls referenced_works_count  \
# 0  {'grobid_xml': False, 'pdf': False}         None                     55
#
#                                     referenced_works  \
# 0  [https://openalex.org/W580385155, https://open...
#
#                                        related_works  \
# 0  [https://openalex.org/W1610586212, https://ope...
#
#                              abstract_inverted_index  \
# 0  {'Abstract': [0], 'Jet': [1], 'energy': [2, 28...
#
#                                       counts_by_year  \
# 0  [{'year': 2026, 'cited_by_count': 9}, {'year':...
#
#                  updated_date         created_date
# 0  2026-07-06T08:01:05.025921  2020-10-29T00:00:00
#
# [1 rows x 49 columns]

# %%
oa_all_pubs['institutions']
# Out:
# 0        []
# 1        []
# 2        []
# 3        []
# 4        []
#          ..
# 76416    []
# 76417    []
# 76418    []
# 76419    []
# 76420    []
# Name: institutions, Length: 76421, dtype: object

# %%
auths = pd.DataFrame(test2['authorships'][0])
auths['institutions']
auths['institution_names'] = auths['institutions'].apply(
    lambda x: [inst['display_name'] for inst in x] if x else []
)

# %%
auths
# Out:
#      author_position                                             author  \
# 0              first  {'id': 'https://openalex.org/A5100769897', 'di...
# 1             middle  {'id': 'https://openalex.org/A5007910787', 'di...
# 2             middle  {'id': 'https://openalex.org/A5088025642', 'di...
# 3             middle  {'id': 'https://openalex.org/A5048474802', 'di...
# 4             middle  {'id': 'https://openalex.org/A5064796035', 'di...
# ...              ...                                                ...
# 2948          middle  {'id': 'https://openalex.org/A5107909554', 'di...
# 2949          middle  {'id': 'https://openalex.org/A5108167659', 'di...
# 2950          middle  {'id': 'https://openalex.org/A5102708152', 'di...
# 2951          middle  {'id': 'https://openalex.org/A5107890339', 'di...
# 2952            last  {'id': 'https://openalex.org/A5105512986', 'di...
#
#                                            institutions countries  \
# 0     [{'id': 'https://openalex.org/I1294671590', 'd...      [FR]
# 1     [{'id': 'https://openalex.org/I24603500', 'dis...      [US]
# 2     [{'id': 'https://openalex.org/I24603500', 'dis...      [US]
# 3     [{'id': 'https://openalex.org/I67311998', 'dis...      [CH]
# 4     [{'id': 'https://openalex.org/I74656192', 'dis...      [DE]
# ...                                                 ...       ...
# 2948  [{'id': 'https://openalex.org/I4210148700', 'd...      [IT]
# 2949  [{'id': 'https://openalex.org/I74656192', 'dis...      [DE]
# 2950  [{'id': 'https://openalex.org/I91136226', 'dis...      [GB]
# 2951  [{'id': 'https://openalex.org/I24603500', 'dis...      [US]
# 2952  [{'id': 'https://openalex.org/I67311998', 'dis...      [CH]
#
#       is_corresponding raw_author_name  \
# 0                False          G. Aad
# 1                False       B. Abbott
# 2                False    D. C. Abbott
# 3                False    A. Abed Abud
# 4                False      K. Abeling
# ...                ...             ...
# 2948             False      A. Zoccoli
# 2949             False         K. Zoch
# 2950             False    T. G. Zorbas
# 2951             False          R. Zou
# 2952             False    L. Zwalinski
#
#                                 raw_affiliation_strings  \
# 0     [CPPM, Aix-Marseille Université, CNRS/IN2P3, M...
# 1     [Department of Physics, University of Massachu...
# 2     [Department of Physics, University of Massachu...
# 3                           [CERN, Geneva, Switzerland]
# 4     [II. Physikalisches Institut, Georg-August-Uni...
# ...                                                 ...
# 2948          [INFN Sezione di Bologna, Bologna, Italy]
# 2949  [II. Physikalisches Institut, Georg-August-Uni...
# 2950  [Department of Physics and Astronomy, Universi...
# 2951  [Department of Physics, University of Massachu...
# 2952                        [CERN, Geneva, Switzerland]
#
#                                   raw_orcid  \
# 0     https://orcid.org/0000-0002-6665-4934
# 1     https://orcid.org/0000-0002-5888-2734
# 2     https://orcid.org/0000-0002-7248-3203
# 3     https://orcid.org/0000-0002-2788-3822
# 4     https://orcid.org/0000-0002-1002-1652
# ...                                     ...
# 2948  https://orcid.org/0000-0002-0993-6185
# 2949  https://orcid.org/0000-0003-2138-6187
# 2950  https://orcid.org/0000-0003-2073-4901
# 2951  https://orcid.org/0000-0002-0542-1264
# 2952  https://orcid.org/0000-0002-9397-2313
#
#                                            affiliations  \
# 0     [{'raw_affiliation_string': 'CPPM, Aix-Marseil...
# 1     [{'raw_affiliation_string': 'Department of Phy...
# 2     [{'raw_affiliation_string': 'Department of Phy...
# 3     [{'raw_affiliation_string': 'CERN, Geneva, Swi...
# 4     [{'raw_affiliation_string': 'II. Physikalische...
# ...                                                 ...
# 2948  [{'raw_affiliation_string': 'INFN Sezione di B...
# 2949  [{'raw_affiliation_string': 'II. Physikalische...
# 2950  [{'raw_affiliation_string': 'Department of Phy...
# 2951  [{'raw_affiliation_string': 'Department of Phy...
# 2952  [{'raw_affiliation_string': 'CERN, Geneva, Swi...
#
#                                       institution_names
# 0     [Centre National de la Recherche Scientifique,...
# 1                 [University of Massachusetts Amherst]
# 2                 [University of Massachusetts Amherst]
# 3          [European Organization for Nuclear Research]
# 4                             [University of Göttingen]
# ...                                                 ...
# 2948  [Istituto Nazionale di Fisica Nucleare, Sezion...
# 2949                          [University of Göttingen]
# 2950                          [University of Sheffield]
# 2951              [University of Massachusetts Amherst]
# 2952       [European Organization for Nuclear Research]
#
# [2953 rows x 10 columns]

# %%
sfu_auths = auths[auths['institution_names'].apply(lambda x: 'Simon Fraser University' in x)]
sfu_auths
# Out:
#      author_position                                             author  \
# 136           middle  {'id': 'https://openalex.org/A5107882155', 'di...
# 578           middle  {'id': 'https://openalex.org/A5039614567', 'di...
# 678           middle  {'id': 'https://openalex.org/A5105505306', 'di...
# 1199          middle  {'id': 'https://openalex.org/A5105788722', 'di...
# 1482          middle  {'id': 'https://openalex.org/A5107883495', 'di...
# 1555          middle  {'id': 'https://openalex.org/A5077377484', 'di...
# 1782          middle  {'id': 'https://openalex.org/A5105505322', 'di...
# 1795          middle  {'id': 'https://openalex.org/A5044331480', 'di...
# 1928          middle  {'id': 'https://openalex.org/A5103713192', 'di...
# 2063          middle  {'id': 'https://openalex.org/A5105504768', 'di...
# 2394          middle  {'id': None, 'display_name': 'S. Singh', 'orci...
# 2474          middle  {'id': 'https://openalex.org/A5007584535', 'di...
# 2705          middle  {'id': 'https://openalex.org/A5019316470', 'di...
#
#                                            institutions countries  \
# 136   [{'id': 'https://openalex.org/I18014758', 'dis...      [CA]
# 578   [{'id': 'https://openalex.org/I18014758', 'dis...      [CA]
# 678   [{'id': 'https://openalex.org/I18014758', 'dis...      [CA]
# 1199  [{'id': 'https://openalex.org/I18014758', 'dis...      [CA]
# 1482  [{'id': 'https://openalex.org/I18014758', 'dis...      [CA]
# 1555  [{'id': 'https://openalex.org/I18014758', 'dis...      [CA]
# 1782  [{'id': 'https://openalex.org/I18014758', 'dis...      [CA]
# 1795  [{'id': 'https://openalex.org/I18014758', 'dis...      [CA]
# 1928  [{'id': 'https://openalex.org/I18014758', 'dis...      [CA]
# 2063  [{'id': 'https://openalex.org/I18014758', 'dis...      [CA]
# 2394  [{'id': 'https://openalex.org/I18014758', 'dis...      [CA]
# 2474  [{'id': 'https://openalex.org/I18014758', 'dis...      [CA]
# 2705  [{'id': 'https://openalex.org/I18014758', 'dis...      [CA]
#
#       is_corresponding     raw_author_name  \
# 136              False      H. Bahrasemani
# 578              False        M. Danninger
# 678              False        E. Drechsler
# 1199             False        B. P. Jaeger
# 1482             False          K. Lehmann
# 1555             False  J. Llorente Merino
# 1782             False       A. Montalbano
# 1795             False             D. Mori
# 1928             False        D. C. O’Neil
# 2063             False            A. Poley
# 2394             False            S. Singh
# 2474             False          B. Stelzer
# 2705             False      M. C. Vetterli
#
#                                 raw_affiliation_strings  \
# 136   [Department of Physics, Simon Fraser Universit...
# 578   [Department of Physics, Simon Fraser Universit...
# 678   [Department of Physics, Simon Fraser Universit...
# 1199  [Department of Physics, Simon Fraser Universit...
# 1482  [Department of Physics, Simon Fraser Universit...
# 1555  [Department of Physics, Simon Fraser Universit...
# 1782  [Department of Physics, Simon Fraser Universit...
# 1795  [Department of Physics, Simon Fraser Universit...
# 1928  [Department of Physics, Simon Fraser Universit...
# 2063  [Department of Physics, Simon Fraser Universit...
# 2394  [Department of Physics, Simon Fraser Universit...
# 2474  [Department of Physics, Simon Fraser Universit...
# 2705  [Department of Physics, Simon Fraser Universit...
#
#                                   raw_orcid  \
# 136                                    None
# 578   https://orcid.org/0000-0002-7807-7484
# 678   https://orcid.org/0000-0002-8773-7640
# 1199  https://orcid.org/0000-0002-5094-5067
# 1482  https://orcid.org/0000-0002-8590-8231
# 1555  https://orcid.org/0000-0003-0027-7969
# 1782  https://orcid.org/0000-0002-5295-432X
# 1795  https://orcid.org/0000-0002-0693-4133
# 1928  https://orcid.org/0000-0003-0325-472X
# 2063  https://orcid.org/0000-0002-4063-0408
# 2394  https://orcid.org/0000-0002-7710-4073
# 2474  https://orcid.org/0000-0003-4091-1784
# 2705  https://orcid.org/0000-0002-7223-2965
#
#                                            affiliations  \
# 136   [{'raw_affiliation_string': 'Department of Phy...
# 578   [{'raw_affiliation_string': 'Department of Phy...
# 678   [{'raw_affiliation_string': 'Department of Phy...
# 1199  [{'raw_affiliation_string': 'Department of Phy...
# 1482  [{'raw_affiliation_string': 'Department of Phy...
# 1555  [{'raw_affiliation_string': 'Department of Phy...
# 1782  [{'raw_affiliation_string': 'Department of Phy...
# 1795  [{'raw_affiliation_string': 'Department of Phy...
# 1928  [{'raw_affiliation_string': 'Department of Phy...
# 2063  [{'raw_affiliation_string': 'Department of Phy...
# 2394  [{'raw_affiliation_string': 'Department of Phy...
# 2474  [{'raw_affiliation_string': 'Department of Phy...
# 2705  [{'raw_affiliation_string': 'Department of Phy...
#
#               institution_names
# 136   [Simon Fraser University]
# 578   [Simon Fraser University]
# 678   [Simon Fraser University]
# 1199  [Simon Fraser University]
# 1482  [Simon Fraser University]
# 1555  [Simon Fraser University]
# 1782  [Simon Fraser University]
# 1795  [Simon Fraser University]
# 1928  [Simon Fraser University]
# 2063  [Simon Fraser University]
# 2394  [Simon Fraser University]
# 2474  [Simon Fraser University]
# 2705  [Simon Fraser University]

# %% [markdown]
# ## explanation
#
# When retrieving a list of works via the API, the authorships list within each work is cut off at 100 authorships objects. When this happens, the boolean is_authors_truncated will be set to true. This affects filtering as well — if you filter works using an author ID or institution ID, you will not receive works where that institution is listed further than 100 places down on the list of authors.

# %% [markdown]
# ## look at top auths in openalex and scival

# %% [markdown]
# ### query 1

# %%
q1_oa_raw.columns
# Out:
# Index(['id', 'doi', 'title', 'display_name', 'relevance_score',
#        'publication_year', 'publication_date', 'ids', 'language',
#        'primary_location', 'type', 'indexed_in', 'open_access', 'authorships',
#        'institutions', 'countries_distinct_count',
#        'institutions_distinct_count', 'corresponding_author_ids',
#        'corresponding_institution_ids', 'apc_list', 'apc_paid', 'fwci',
#        'has_fulltext', 'cited_by_count', 'citation_normalized_percentile',
#        'cited_by_percentile_year', 'biblio', 'is_retracted', 'is_paratext',
#        'is_xpac', 'primary_topic', 'topics', 'keywords', 'concepts', 'mesh',
#        'locations_count', 'locations', 'best_oa_location',
#        'sustainable_development_goals', 'awards', 'funders', 'has_content',
#        'content_urls', 'referenced_works_count', 'referenced_works',
#        'related_works', 'abstract_inverted_index', 'counts_by_year',
#        'updated_date', 'created_date'],
#       dtype='object')

# %%
sfu_author_rankings = get_sfu_author_rankings(q3_oa_raw)
sfu_author_rankings.head(20)
# Out:
#                             author_name                         author_id  \
# pub_rank
# 1                         Atiya Mahmood  https://openalex.org/A5027802940
# 2                       Michael Howlett  https://openalex.org/A5077475073
# 3                     Allen E. Thornton  https://openalex.org/A5018971948
# 4                         Ahmed Al‐Rawi  https://openalex.org/A5050245548
# 5                       Habib Chaudhury  https://openalex.org/A5014665875
# 6                        Meghan Winters  https://openalex.org/A5023136423
# 7                            Kelley Lee  https://openalex.org/A5019363540
# 8         Andrés M. Cisneros‐Montemayor  https://openalex.org/A5041047135
# 9                       Rachel Weldrick  https://openalex.org/A5088991237
# 10                  Kishore Seetharaman  https://openalex.org/A5081955001
# 11                     Julian M. Somers  https://openalex.org/A5083672700
# 12                      Andréanne Doyon  https://openalex.org/A5020845547
# 13                           Meg Holden  https://openalex.org/A5067275272
# 14                        Kanna Hayashi  https://openalex.org/A5029471416
# 15                      Lupin Battersby  https://openalex.org/A5055338819
# 16                          Gary Teeple  https://openalex.org/A5008437652
# 17                  Shira M. Goldenberg  https://openalex.org/A5026561655
# 18                        Joe Humphries  https://openalex.org/A5058383635
# 19                    Genevieve Johnson  https://openalex.org/A5055958025
# 20                       Daniel R Y Gan  https://openalex.org/A5075926575
#
#           pub_count  total_citations  citation_rank  \
# pub_rank
# 1                26              172             20
# 2                25              964              2
# 3                22              142             30
# 4                19              148             28
# 5                17              118             36
# 6                16              280              9
# 7                16              580              4
# 8                14              334              8
# 9                13              110             39
# 10               12               66             60
# 11               12              122             33
# 12               10              154             27
# 13               10               98             43
# 14                9               78             54
# 15                9                0            498
# 16                8                6            301
# 17                8              214             12
# 18                7               69             56
# 19                7               46             84
# 20                7                5            314
#
#                                                        dois
# pub_rank
# 1         [https://doi.org/10.1017/s0144686x21000234, ht...
# 2         [https://doi.org/10.1002/epa2.1142, https://do...
# 3         [https://doi.org/10.1007/s00406-023-01664-0, h...
# 4         [https://doi.org/10.1007/978-3-031-61819-2_4, ...
# 5         [https://doi.org/10.1002/gps.5985, https://doi...
# 6         [https://doi.org/10.1016/j.aap.2020.105540, ht...
# 7         [https://doi.org/10.1007/s10903-022-01422-9, h...
# 8         [https://doi.org/10.1007/978-981-19-5065-0_4, ...
# 9         [https://doi.org/10.1080/01634372.2022.2087128...
# 10        [https://doi.org/10.1080/02697459.2024.2425249...
# 11        [https://doi.org/10.1007/s10488-020-01008-3, h...
# 12        [https://doi.org/10.1007/978-981-99-2760-9_4, ...
# 13        [https://doi.org/10.1007/978-3-030-89559-4, ht...
# 14        [https://doi.org/10.1016/j.drugalcdep.2021.108...
# 15        [https://doi.org/10.1007/978-3-030-34390-3_7, ...
# 16        [https://doi.org/10.1007/978-3-031-68020-5_1, ...
# 17        [https://doi.org/10.1007/978-3-030-64171-9, ht...
# 18        [https://doi.org/10.1017/s0144686x21000234, ht...
# 19        [https://doi.org/10.1007/s13178-020-00452-y, h...
# 20        [https://doi.org/10.1080/23748834.2024.2314382...

# %%
sfu_author_rankings[sfu_author_rankings['author_name'].str.contains('Kaida')]
# Out:
#            author_name                         author_id  pub_count  \
# pub_rank
# 71        Angela Kaida  https://openalex.org/A5091089188          3
#
#           total_citations  citation_rank  \
# pub_rank
# 71                     37            100
#
#                                                        dois
# pub_rank
# 71        [https://doi.org/10.1002/jia2.25913, https://d...

# %%
sfu_author_rankings_scopus = get_sfu_author_rankings_scopus(q3_sv_raw)
sfu_author_rankings_scopus.head(20)
# Out:
#                                  author_name    author_id  pub_count  \
# pub_rank
# 1                        Howlett, Michael P.   7004315057         35
# 2                             Hayashi, Kanna  33267650300         26
# 3                         Winters, Meghan L.  16235208800         23
# 4                         Thornton, Allen E.   7101607212         17
# 5         Cisneros-Montemayor, Andrés Miguel  36094057100         17
# 6                               DeBeck, Kora  16063277500         14
# 7                                Lee, Kelley  55540777300         13
# 8                       Goldenberg, Shira M.  35310255700         12
# 9                          Somers, Julian M.   8071300500         12
# 10                          Kaida, Angela K.  15048041200         11
# 11                            Al Rawi, Ahmed  55683085700         11
# 12                         Mahmood, Atiya N.  14047242400         11
# 13                    Chaudhury, Habib Sadat   9039040400         10
# 14                           Hogg, Robert S.   7201804367         10
# 15                         Snyder, Jeremy C.  24170239100          8
# 16                          Weldrick, Rachel  57200444598          8
# 17                               Holden, Meg  13406026800          8
# 18                   Salomon, Anne Katherine   7005421580          7
# 19                          Salters, Kate A.  54417810000          7
# 20                       Card, Kiffer George  57188649371          6
#
#           total_citations  citation_rank  \
# pub_rank
# 1                    1412              1
# 2                     289             11
# 3                     421              5
# 4                     217             15
# 5                     322              8
# 6                     132             34
# 7                     378              6
# 8                     256             12
# 9                     120             38
# 10                     93             49
# 11                     86             56
# 12                    195             22
# 13                    147             30
# 14                     95             48
# 15                     80             61
# 16                    108             41
# 17                     90             51
# 18                    149             29
# 19                     51             80
# 20                     53             74
#
#                                                        dois
# pub_rank
# 1         [10.1002/epa2.1142, 10.1007/978-3-031-25689-9,...
# 2         [10.1016/j.addbeh.2020.106793, 10.1016/j.druga...
# 3         [10.1016/j.aap.2020.105540, 10.1016/j.healthpl...
# 4         [10.1007/s00406-023-01664-0, 10.1016/S2468-266...
# 5         [10.1007/978-981-19-5065-0_4, 10.1007/s11160-0...
# 6         [10.1016/j.drugalcdep.2021.108829, 10.1016/j.d...
# 7         [10.1007/s10903-022-01422-9, 10.1016/S0140-673...
# 8         [10.1007/978-3-030-64171-9, 10.1007/978-3-030-...
# 9         [10.1007/s10488-020-01008-3, 10.1007/s11524-02...
# 10        [10.1002/jia2.25913, 10.1007/s10461-019-02463-...
# 11        [10.1017/9781009001021.026, 10.1080/10410236.2...
# 12        [10.1017/S0144686X21000234, 10.1080/01634372.2...
# 13        [10.1002/gps.5985, 10.1007/s10433-020-00599-y,...
# 14        [10.1007/s10461-019-02463-2, 10.1007/s10903-02...
# 15        [10.1016/j.jcyt.2020.09.002, 10.1177/136345932...
# 16        [10.1080/01634372.2022.2087128, 10.1080/027019...
# 17        [10.1007/s42413-020-00062-x, 10.1016/j.cities....
# 18        [10.1002/pan3.10090, 10.1002/pan3.10211, 10.10...
# 19        [10.1080/02673037.2021.1900548, 10.1080/095401...
# 20        [10.1007/s10903-022-01422-9, 10.1177/002073142...

# %%
sfu_author_rankings_scopus[sfu_author_rankings_scopus['author_name'].str.contains('Kishore')]
# Out:
#                    author_name    author_id  pub_count  total_citations  \
# pub_rank
# 23        Seetharaman, Kishore  57214320425          6              101
#
#           citation_rank                                               dois
# pub_rank
# 23                   43  [10.1080/21650020.2023.2296891, 10.1093/geront...
