# %% [markdown]
# # Publisher comparison for CERC queries
# To better understand where the large difference in publicaton lists between SciVal and OpenAlex for the three CERC queries, we look in more detail at the publishers of the papers listed in each query.

# %%
# import libraries 

import pandas as pd
import numpy as np
import json
import ast
import fuzzywuzzy
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from datetime import datetime
from tqdm import tqdm 
from collections import defaultdict
import matplotlib.pyplot as plt

# q1
q1_oa_raw = pd.read_csv('./cerc_results/query1.csv')
q1_sv_raw = pd.read_excel('./cerc_results/query1_SCIVAL.xlsx', sheet_name="rio results")

# q2
q2_oa_raw = pd.read_csv('./cerc_results/query2.csv')
q2_sv_raw = pd.read_excel('./cerc_results/query2_SCIVAL.xlsx', sheet_name="rio results")

# q3
q3_oa_raw = pd.read_csv('./cerc_results/query3.csv')
q3_sv_raw = pd.read_excel('./cerc_results/query3_SCIVAL.xlsx', sheet_name="rio results")

# %%
import os
print(os.path.abspath('./cerc_results/query1_SCIVAL.xlsx'))
print(os.getcwd())
# Out:
# c:\Users\tania\OneDrive - TM-IT Consulting Inc\Documents\juan\cerc_results\query1_SCIVAL.xlsx
# c:\Users\tania\OneDrive - TM-IT Consulting Inc\Documents\juan

# %% [markdown]
# ## Query 1

# %% [markdown]
# ### OpenAlex

# %%
q1_oa_raw.columns
# Out:
# Index(['id', 'doi', 'title', 'display_name', 'relevance_score',
#        'publication_year', 'publication_date', 'ids', 'language',
#        'primary_location', 'type', 'indexed_in', 'open_access', 'authorships',
#        'institutions', 'countries_distinct_count',
#        'institutions_distinct_count', 'corresponding_author_ids',
#        'corresponding_institution_ids', 'apc_list', 'apc_paid', 'fwci',
#        'has_fulltext', 'cited_by_count', 'citation_normalized_percentile',
#        'cited_by_percentile_year', 'biblio', 'is_retracted', 'is_paratext',
#        'is_xpac', 'primary_topic', 'topics', 'keywords', 'concepts', 'mesh',
#        'locations_count', 'locations', 'best_oa_location',
#        'sustainable_development_goals', 'awards', 'funders', 'has_content',
#        'content_urls', 'referenced_works_count', 'referenced_works',
#        'related_works', 'abstract_inverted_index', 'counts_by_year',
#        'updated_date', 'created_date'],
#       dtype='object')

# %% [markdown]
# i want to keep id, doi, title, publication year, extract publisher name from primary location, extract is oa from open_access, fwci, cited_by_count only

# %%
q1_oa_clean = q1_oa_raw.copy()
q1_oa_clean['publisher_TEMP'] = q1_oa_clean['primary_location'].apply(lambda x: ast.literal_eval(x))
q1_oa_clean['journal_name'] = q1_oa_clean['publisher_TEMP'].apply(lambda x: x['raw_source_name'])
q1_oa_clean['publisher_TEMP2'] = q1_oa_clean['publisher_TEMP'].apply(lambda x: x['source'])
q1_oa_clean['publisher_name'] = q1_oa_clean['publisher_TEMP2'].apply(lambda x: x['host_organization_name'] if x is not None else None)
q1_oa_clean['oa_TEMP'] = q1_oa_clean['open_access'].apply(lambda x: ast.literal_eval(x))
q1_oa_clean['oa_status'] = q1_oa_clean['oa_TEMP'].apply(lambda x: x['is_oa'])
q1_oa_clean = q1_oa_clean[['id', 'doi', 'title', 'publication_year', 'journal_name', 'publisher_name', 'oa_status', 'fwci', 'cited_by_count']]

#q1_oa_clean

# %%
q1_oa_publisher_groups = pd.DataFrame(q1_oa_clean.groupby(['publisher_name']).count()['publication_year']).sort_values(by='publication_year', ascending=False).reset_index().rename(columns={'publication_year': 'publication_count'})
q1_oa_publisher_groups
# Out:
#                                        publisher_name  publication_count
# 0                                         Elsevier BV                 97
# 1   Institute of Electrical and Electronics Engineers                 85
# 2                     Springer Science+Business Media                 49
# 3                                               Wiley                 49
# 4      Multidisciplinary Digital Publishing Institute                 32
# ..                                                ...                ...
# 70                       Surveillance Studies Network                  1
# 71                  Universidade Federal de São Paulo                  1
# 72                          The Company of Biologists                  1
# 73                   University of Huddersfield Press                  1
# 74                           University of Manchester                  1
#
# [75 rows x 2 columns]

# %%
q1_oa_big_pub = q1_oa_publisher_groups[q1_oa_publisher_groups['publication_count']>3]
q1_oa_big_pub.head()
# Out:
#                                       publisher_name  publication_count
# 0                                        Elsevier BV                 97
# 1  Institute of Electrical and Electronics Engineers                 85
# 2                    Springer Science+Business Media                 49
# 3                                              Wiley                 49
# 4     Multidisciplinary Digital Publishing Institute                 32

# %%
# Create the bar graph
plt.bar(q1_oa_big_pub['publisher_name'], q1_oa_big_pub['publication_count'])

# Add labels and a title
plt.xlabel("Publisher Name")
plt.ylabel("Publication Count")
plt.title("Query 1 OA publishers with >3 publications")
plt.xticks(range(len(q1_oa_big_pub['publisher_name'])), q1_oa_big_pub['publisher_name'], rotation='vertical') # or rotation=90

# Display the plot
plt.show()

# %% [markdown]
# ### SciVal

# %%
q1_sv_raw.columns
# Out:
# Index(['Authors', 'Author full names', 'Author(s) ID', 'Title', 'Year',
#        'Source title', 'Volume', 'Issue', 'Art. No.', 'Page start', 'Page end',
#        'Cited by', 'DOI', 'Link', 'Affiliations', 'Authors with affiliations',
#        'Correspondence Address', 'Editors', 'Publisher', 'ISSN', 'ISBN',
#        'CODEN', 'PubMed ID', 'Language of Original Document',
#        'Abbreviated Source Title', 'Document Type', 'Publication Stage',
#        'Open Access', 'Source', 'EID'],
#       dtype='object')

# %%
test = q1_sv_raw.copy()
test['num_auths'] = test['Authors'].apply(lambda x: len(str.split(x, ';')))
#test
# Out:
#                                                Authors  \
# 0    Aghanim, N.; Akrami, Y.; Ashdown, M.; Aumont, ...
# 1    Zhang, J.; Lei, J.; Xie, W.; Fang, Z.; Li, Y.;...
# 2    Xiang, F.; Qin, Y.; Mo, K.; Xia, Y.; Zhu, H.; ...
# 3    Szot, A.; Clegg, A.; Undersander, E.; Wijmans,...
# 4    Shahabi, H.; Shirzadi, A.; Ghaderi, K.; Omidva...
# ..                                                 ...
# 945                             Amini, J.; Moallem, M.
# 946  Rosychuk, R.J.; Bachman, J.W.N.; Chen, A.; Hu,...
# 947                         Hynes, C.G.; Vaughan, R.G.
# 948           Meyer, K.E.; Ding, Y.; Li, J.; Zhang, H.
# 949                              Donati, D.; Stead, D.
#
#                                      Author full names  \
# 0    Aghanim, Nabila (6701390827); Akrami, Yashar (...
# 1    Zhang, Jiaqing (57201893177); Lei, Jie (366637...
# 2    Xiang, Fanbo (57219588888); Qin, Yuzhe (572195...
# 3    Szot, Andrew (57223233772); Clegg, Alexander W...
# 4    Shahabi, Himan (57213611082); Shirzadi, Ataoll...
# ..                                                 ...
# 945  Amini, Jalal (57200975364); Moallem, Mehrdad (...
# 946  Rosychuk, Rhonda Jean (7003299198); Bachman, J...
# 947  Hynes, Christopher G. (14009855500); Vaughan, ...
# 948  Meyer, Klaus E. (7401793822); Ding, Yuan (7404...
# 949  Donati, Davide (57202339459); Stead, Douglas (...
#
#                                           Author(s) ID  \
# 0    6701390827; 35387346400; 6603626885; 571954962...
# 1    57201893177; 36663710700; 56768656200; 3836126...
# 2    57219588888; 57219507801; 57201313394; 5721958...
# 3    57223233772; 56963583300; 57219481691; 5720131...
# 4    57213611082; 57209036611; 55575371100; 2592605...
# ..                                                 ...
# 945                           57200975364; 35609219200
# 946  7003299198; 57220203033; 57219394662; 35229913300
# 947                            14009855500; 7201481830
# 948   7401793822; 7404136394; 57216939987; 53873458900
# 949                            57202339459; 7006004275
#
#                                                  Title  Year  \
# 0    Planck 2018 results: V. CMB power spectra and ...  2020
# 1    SuperYOLO: Super Resolution Assisted Object De...  2023
# 2    Sapien: A simulated part-based interactive ENv...  2020
# 3    Habitat 2.0: Training Home Assistants to Rearr...  2021
# 4    Flood detection and susceptibility mapping usi...  2020
# ..                                                 ...   ...
# 945  Logic-based space-vector modulation for neutra...  2020
# 946  Handling coarsened age information in the anal...  2020
# 947  Detection of Electric and Magnetic Dipole Mome...  2020
# 948  Overcoming distrust: How state-owned enterpris...  2020
# 949  Potential applications of multi-sensor remote ...  2020
#
#                                           Source title Volume Issue Art. No.  \
# 0                           Astronomy and Astrophysics    641   NaN       A5
# 1    IEEE Transactions on Geoscience and Remote Sen...     61   NaN  5605415
# 2    Proceedings of the IEEE Computer Society Confe...    NaN   NaN  9156706
# 3    Advances in Neural Information Processing Systems      1   NaN      NaN
# 4                                       Remote Sensing     12     2      266
# ..                                                 ...    ...   ...      ...
# 945                              IET Power Electronics     13    19      NaN
# 946                   BMC Medical Research Methodology     20     1      297
# 947  2020 IEEE International Symposium on Antennas ...    NaN   NaN  9330408
# 948   Multinational Enterprises and Emerging Economies    NaN   NaN      NaN
# 949  Rock Mechanics for Natural Resources and Infra...    NaN   NaN      NaN
#
#     Page start  ...  CODEN   PubMed ID Language of Original Document  \
# 0          NaN  ...  AAEJA         NaN                       English
# 1          NaN  ...  IGRSD         NaN                       English
# 2        11094  ...  PIVRE         NaN                       English
# 3          251  ...    NaN         NaN                       English
# 4          NaN  ...    NaN         NaN                       English
# ..         ...  ...    ...         ...                           ...
# 945       4462  ...    NaN         NaN                       English
# 946        NaN  ...    NaN  33287720.0                       English
# 947        247  ...    NaN         NaN                       English
# 948        291  ...    NaN         NaN                       English
# 949        536  ...    NaN         NaN                       English
#
#                               Abbreviated Source Title     Document Type  \
# 0                                   Astron. Astrophys.           Article
# 1                        IEEE Trans Geosci Remote Sens           Article
# 2    Proc IEEE Comput Soc Conf Comput Vision Patter...  Conference paper
# 3                       Adv. neural inf. proces. syst.  Conference paper
# 4                                         Remote Sens.           Article
# ..                                                 ...               ...
# 945                                IET Power Electron.           Article
# 946                            BMC Med. Res. Methodol.           Article
# 947  IEEE Int. Symp. Antennas Propag. North Am. Rad...  Conference paper
# 948     Multinational Enterprises and Emerg. Economies      Book chapter
# 949  Rock Mech. Natural Resour. Infrastruct. Dev. -...  Conference paper
#
#     Publication Stage                                        Open Access  \
# 0               Final  All Open Access; Green Accepted Open Access; G...
# 1               Final                                                NaN
# 2               Final                                                NaN
# 3               Final                                                NaN
# 4               Final  All Open Access; Gold Open Access; Green Accep...
# ..                ...                                                ...
# 945             Final                                                NaN
# 946             Final  All Open Access; Gold Open Access; Green Accep...
# 947             Final                                                NaN
# 948             Final                                                NaN
# 949             Final                                                NaN
#
#      Source                 EID num_auths
# 0    Scopus  2-s2.0-85091948619       100
# 1    Scopus  2-s2.0-85151518351         6
# 2    Scopus  2-s2.0-85094479575        14
# 3    Scopus  2-s2.0-85121022702        21
# 4    Scopus  2-s2.0-85081087241        17
# ..      ...                 ...       ...
# 945  Scopus  2-s2.0-85102394687         2
# 946  Scopus  2-s2.0-85097307183         4
# 947  Scopus  2-s2.0-85101641412         2
# 948  Scopus  2-s2.0-85139711973         4
# 949  Scopus  2-s2.0-85084654734         2
#
# [950 rows x 31 columns]

# %%
test['num_auths'].unique()
# Out:
# array([100,   6,  14,  21,  17,   7,   8,  27,   9,  24,  29,  10,   4,
#          3,  54,  25,   5,  11,   2,   1,  12,  32,  59,  20,  48,  15,
#         18,  13,  36,  19,  28,  16,  44,  22,  46,  55,  45,  78,  77])

# %%
test[test['num_auths'] == 100]
# Out:
#                                                Authors  \
# 0    Aghanim, N.; Akrami, Y.; Ashdown, M.; Aumont, ...
# 7    Aad, G.; Abbott, B.; Abbott, D.C.; Abed Abud, ...
# 8    Aad, G.; Abbott, B.; Abbott, D.C.; Abed Abud, ...
# 12   Akrami, Y.; Ashdown, M.; Aumont, J.; Baccigalu...
# 14   Akrami, Y.; Andersen, K.J.; Ashdown, M.; Bacci...
# 17   Aad, G.; Abbott, B.; Abbott, D.C.; Abed Abud, ...
# 24   Akrami, Y.; Ashdown, M.; Aumont, J.; Baccigalu...
# 29   Aghanim, N.; Akrami, Y.; Alves, M.I.R.; Ashdow...
# 30   Aghanim, N.; Akrami, Y.; Ashdown, M.; Aumont, ...
# 33   Aad, G.; Abbott, B.; Abbott, D.C.; Abed Abud, ...
# 36   Aad, G.; Abbott, B.; Abbott, D.C.; Abed Abud, ...
# 41   Aad, G.; Abbott, B.; Abbott, D.C.; Abed Abud, ...
# 43   Aad, G.; Abbott, B.; Abbott, D.C.; Abed Abud, ...
# 45   Aad, G.; Abbott, B.; Abbott, D.C.; Abeling, K....
# 58   Aad, G.; Abbott, B.; Abbott, D.C.; Abed Abud, ...
# 67   Aad, G.; Abbott, B.; Abbott, D.C.; Abed Abud, ...
# 106  Cmero, M.; Yuan, K.; Ong, C.S.; Schroeder, J.;...
# 107  Aad, G.; Abbott, B.; Abbott, D.C.; Abed Abud, ...
# 118  Rubanova, Y.; Shi, R.; Harrigan, C.F.; Li, R.;...
# 123  Aad, G.; Abbott, B.; Abbott, D.C.; Abed Abud, ...
# 127  Aad, G.; Abbott, B.; Abbott, D.C.; Abeling, K....
# 131  Aad, G.; Abbott, B.; Abbott, D.C.; Abed Abud, ...
# 146  Akrami, Y.; Argüeso, F.; Ashdown, M.; Aumont, ...
# 148  Aad, G.; Abbott, B.; Abeling, K.; Abicht, N.J....
# 197  Aad, G.; Abbott, B.; Abbott, D.C.; Abed Abud, ...
# 218  Aad, G.; Abbott, B.; Abbott, D.C.; Abed Abud, ...
# 233  Aad, G.; Abbott, B.; Abbott, D.C.; Abed Abud, ...
# 334  Aad, G.; Abbott, B.; Abeling, K.; Abicht, N.J....
# 347  Aad, G.; Aakvaag, E.; Abbott, B.; Abdelhameed,...
# 357  Aad, G.; Abbott, B.; Abbott, D.C.; Abed Abud, ...
# 385  Aad, G.; Abbott, B.; Abbott, D.C.; Abed Abud, ...
# 465  Aad, G.; Abbott, B.; Abeling, K.; Abicht, N.J....
# 491  Aad, G.; Abbott, B.; Abbott, D.C.; Abed Abud, ...
#
# 357  Emulating the impact of additional proton–prot...  2022
# 385  Measurement of the energy response of the ATLA...  2022
# 465  Performance and calibration of quark/gluon-jet...  2024
# 491  Measurements of sensor radiation damage in the...  2021
# 523  Measurements of Zγ+jets differential cross sec...  2023
# 580  Measurement of the cross-sections of the elect...  2023
# 605                      The ATLAS fast TracKer system  2021
# 629  Measurement of jet substructure in boosted For...  2024
# 639  Search for leptonic charge asymmetry in tt¯ W ...  2023
# 686  Sensor response and radiation damage effects f...  2024
# 751  Beam-induced backgrounds measured in the ATLAS...  2024
# 755  Erratum to: Observation of four-top-quark prod...  2024
#
#                                           Source title Volume Issue Art. No.  \
# 0                           Astronomy and Astrophysics    641   NaN       A5
# 7                          European Physical Journal C     81     8      689
# 8                           Journal of Instrumentation     15     9   P09015
# 12                          Astronomy and Astrophysics    641   NaN       A4
# 14                          Astronomy and Astrophysics    643   NaN      A42
# 17                             Physical Review Letters    125    13   131801
# 24                          Astronomy and Astrophysics    641   NaN      A11
# 29                          Astronomy and Astrophysics    641   NaN      A12
# 30                          Astronomy and Astrophysics    641   NaN       A3
# 33                             Physical Review Letters    131    15   151902
# 36                         European Physical Journal C     82     1       95
# 41              Computing and Software for Big Science      6     1        7
# 43                                   Physical Review D    101     5    52007
# 45                         European Physical Journal C     83     8      728
# 58                                   Physical Review C    104     1    14903
# 67                      Journal of High Energy Physics   2020     8       80
# 106                              Nature Communications     11     1      730
# 107                     Journal of High Energy Physics   2020     7       44
# 118                              Nature Communications     11     1      731
# 123  Physics Letters, Section B: Nuclear, Elementar...    816   NaN   136190
# 127                     Journal of High Energy Physics   2023     7      166
# 131                     Journal of High Energy Physics   2020     9       49
# 146                         Astronomy and Astrophysics    641   NaN       A2
# 148                         Journal of Instrumentation     18    11   T11004
# 197             Computing and Software for Big Science      8     1        7
# 218                        European Physical Journal C     81    12     1087
# 233                     Journal of High Energy Physics   2022     8       89
# 334                        European Physical Journal C     83     8      761
# 347                        European Physical Journal C     84     9      984
# 357             Computing and Software for Big Science      6     1        3
# 385                        European Physical Journal C     82     3      223
# 465                                  Chinese Physics C     48     2    23001
# 491                         Journal of Instrumentation     16     8   P08025
# 523                     Journal of High Energy Physics   2023     7       72
# 580  Physics Letters, Section B: Nuclear, Elementar...    846   NaN   138222
# 605                         Journal of Instrumentation     16     7   P07006
# 629                                  Physical Review D    109    11   112016
# 639                     Journal of High Energy Physics   2023     7       33
# 686                         Journal of Instrumentation     19    10      NaN
# 751                         Journal of Instrumentation     19     6   P06014
# 755                        European Physical Journal C     84     2      156
#
#     Page start  ...  CODEN   PubMed ID Language of Original Document  \
# 0          NaN  ...  AAEJA         NaN                       English
# 7          NaN  ...    NaN         NaN                       English
# 8          NaN  ...    NaN         NaN                       English
# 12         NaN  ...  AAEJA         NaN                       English
# 14         NaN  ...  AAEJA         NaN                       English
# 17         NaN  ...  PRLTA  33034503.0                       English
# 24         NaN  ...  AAEJA         NaN                       English
# 29         NaN  ...  AAEJA         NaN                       English
# 30         NaN  ...  AAEJA         NaN                       English
# 33         NaN  ...  PRLTA  37897770.0                       English
# 36         NaN  ...    NaN         NaN                       English
# 41         NaN  ...    NaN         NaN                       English
# 43         NaN  ...    NaN         NaN                       English
# 45         NaN  ...    NaN         NaN                       English
# 58         NaN  ...    NaN         NaN                       English
# 67         NaN  ...    NaN         NaN                       English
# 106        NaN  ...    NaN         NaN                           NaN
# 107        NaN  ...    NaN         NaN                       English
# 118        NaN  ...    NaN         NaN                           NaN
# 123        NaN  ...  PYLBA         NaN                       English
# 127        NaN  ...    NaN         NaN                       English
# 131        NaN  ...    NaN         NaN                       English
# 146        NaN  ...  AAEJA         NaN                       English
# 148        NaN  ...    NaN         NaN                       English
# 197        NaN  ...    NaN         NaN                       English
# 218        NaN  ...    NaN         NaN                       English
# 233        NaN  ...    NaN         NaN                       English
# 334        NaN  ...    NaN         NaN                       English
# 347        NaN  ...    NaN         NaN                       English
# 357        NaN  ...    NaN         NaN                       English
# 385        NaN  ...    NaN         NaN                       English
# 465        NaN  ...    NaN         NaN                       English
# 491        NaN  ...    NaN         NaN                       English
# 523        NaN  ...    NaN         NaN                       English
# 580        NaN  ...  PYLBA         NaN                       English
# 605        NaN  ...    NaN         NaN                       English
# 629        NaN  ...    NaN         NaN                       English
# 639        NaN  ...    NaN         NaN                       English
# 686        NaN  ...    NaN         NaN                       English
# 751        NaN  ...    NaN         NaN                       English
# 755        NaN  ...    NaN         NaN                       English
#
#                              Abbreviated Source Title Document Type  \
# 0                                  Astron. Astrophys.       Article
# 7                                     Eur. Phys. J. C       Article
# 8                                         J. Instrum.       Article
# 12                                 Astron. Astrophys.       Article
# 14                                 Astron. Astrophys.       Article
# 17                                      Phys Rev Lett       Article
# 24                                 Astron. Astrophys.       Article
# 29                                 Astron. Astrophys.       Article
# 30                                 Astron. Astrophys.       Article
# 33                                      Phys Rev Lett       Article
# 36                                    Eur. Phys. J. C       Article
# 41                            Comput. Softw. Big Sci.       Article
# 43                                        Phy. Rev. D       Article
# 45                                    Eur. Phys. J. C       Article
# 58                                       Phys. Rev. C       Article
# 67                               J. High Energy Phys.       Article
# 106                                               NaN           NaN
# 107                              J. High Energy Phys.       Article
# 118                                               NaN           NaN
# 123  Phys Lett Sect B Nucl Elem Part High-Energy Phys       Article
# 127                              J. High Energy Phys.       Article
# 131                              J. High Energy Phys.       Article
# 146                                Astron. Astrophys.       Article
# 148                                       J. Instrum.       Article
# 197                           Comput. Softw. Big Sci.       Article
# 218                                   Eur. Phys. J. C       Article
# 233                              J. High Energy Phys.       Article
# 334                                   Eur. Phys. J. C       Article
# 347                                   Eur. Phys. J. C       Article
# 357                           Comput. Softw. Big Sci.       Article
# 385                                   Eur. Phys. J. C       Article
# 465                                     Chin. Phys. C       Article
# 491                                       J. Instrum.       Article
# 523                              J. High Energy Phys.       Article
# 580  Phys Lett Sect B Nucl Elem Part High-Energy Phys       Article
# 605                                       J. Instrum.       Article
# 629                                       Phy. Rev. D       Article
# 639                              J. High Energy Phys.       Article
# 686                                       J. Instrum.       Article
# 67   Scopus  2-s2.0-85089974543       100
# 106     NaN                 NaN       100
# 107  Scopus  2-s2.0-85087722167       100
# 118     NaN                 NaN       100
# 123  Scopus  2-s2.0-85112780142       100
# 127  Scopus  2-s2.0-85165876369       100
# 131  Scopus  2-s2.0-85090330843       100
# 146  Scopus  2-s2.0-85091910244       100
# 148  Scopus  2-s2.0-85180761391       100
# 197  Scopus  2-s2.0-85189330049       100
# 218  Scopus  2-s2.0-85120958752       100
# 233  Scopus  2-s2.0-85135791758       100
# 334  Scopus  2-s2.0-85179172081       100
# 347  Scopus  2-s2.0-85205704534       100
# 357  Scopus  2-s2.0-85124276335       100
# 385  Scopus  2-s2.0-85134070625       100
# 465  Scopus  2-s2.0-85185169176       100
# 491  Scopus  2-s2.0-85114558026       100
# 523  Scopus  2-s2.0-85165297044       100
# 580  Scopus  2-s2.0-85176131303       100
# 605  Scopus  2-s2.0-85113807973       100
# 629  Scopus  2-s2.0-85198392709       100
# 639  Scopus  2-s2.0-85164102382       100
# 686  Scopus  2-s2.0-85206495952       100
# 751  Scopus  2-s2.0-85196151175       100
# 755  Scopus  2-s2.0-85190710850       100
#
# [41 rows x 31 columns]

# %%
plt.hist(test['num_auths'], color='skyblue', edgecolor='black')
plt.xlabel('Number of authors')
plt.ylabel('number of punlications')
plt.show()

# %% [markdown]
# i want to keep id, doi, title, publication year, extract publisher name from primary location, extract is oa from open_access, ~~fwci~~, cited_by_count only

# %%
q1_sv_clean = q1_sv_raw.copy()
q1_sv_clean = q1_sv_clean[['EID', 'DOI', 'Title', 'Year', 'Publisher', 'Source title', 'Open Access', 'Cited by']]

#q1_sv_clean

# %%
q1_sv_publisher_groups = pd.DataFrame(q1_sv_clean.groupby(['Publisher']).count()['Year']).sort_values(by='Year', ascending=False).reset_index().rename(columns={'Year': 'publication_count'})
q1_sv_publisher_groups
# Out:
#                                              Publisher  publication_count
# 0    Institute of Electrical and Electronics Engine...                192
# 1                                        Elsevier B.V.                 52
# 2                                         Elsevier Ltd                 47
# 3                              John Wiley and Sons Inc                 37
# 4    Springer Science and Business Media Deutschlan...                 36
# ..                                                 ...                ...
# 170                          Web Portal Ubiquity Press                  1
# 171                                    Wiley-Blackwell                  1
# 172                                   Wiley-VCH Verlag                  1
# 173                                   World Scientific                  1
# 174  World Scientific Publishing Co. Pte Ltd wspc@w...                  1
#
# [175 rows x 2 columns]

# %%
q1_sv_big_pub = q1_sv_publisher_groups[q1_sv_publisher_groups['publication_count']>3]
#q1_oa_big_pub.head()

# Create the bar graph
plt.bar(q1_sv_big_pub['Publisher'], q1_sv_big_pub['publication_count'])

plt.xlabel("Publisher Name")
plt.ylabel("Publication Count")
plt.title("Query 1 SV publishers with >3 publications")
plt.xticks(range(len(q1_sv_big_pub['Publisher'])), q1_sv_big_pub['Publisher'], rotation='vertical') 

plt.show()

# %% [markdown]
# SciVal somehow has way more distinct publishers - this is partally due to the fact that their name standardization is worse than in OpenAlex (surprisingly?). Also interestingly, SciVal has way more publications under IEEE than OpenAlex. My suspicion is that the big publications arent being caught by OpenAlex for some reason, but they are by SciVal (as per our investigation of some specific publications earlier). Will run the same for Query 2 and 3 and start digging into authors in more detail.

# %% [markdown]
# ## Query 2

# %% [markdown]
# ### OpenAlex

# %% [markdown]
# i want to keep id, doi, title, publication year, extract publisher name from primary location, extract is oa from open_access, fwci, cited_by_count only

# %%
q2_oa_clean = q2_oa_raw.copy()
q2_oa_clean['publisher_TEMP'] = q2_oa_clean['primary_location'].apply(lambda x: ast.literal_eval(x))
q2_oa_clean['journal_name'] = q2_oa_clean['publisher_TEMP'].apply(lambda x: x['raw_source_name'])
q2_oa_clean['publisher_TEMP2'] = q2_oa_clean['publisher_TEMP'].apply(lambda x: x['source'])
q2_oa_clean['publisher_name'] = q2_oa_clean['publisher_TEMP2'].apply(lambda x: x['host_organization_name'] if x is not None else None)
q2_oa_clean['oa_TEMP'] = q2_oa_clean['open_access'].apply(lambda x: ast.literal_eval(x))
q2_oa_clean['oa_status'] = q2_oa_clean['oa_TEMP'].apply(lambda x: x['is_oa'])
q2_oa_clean = q2_oa_clean[['id', 'doi', 'title', 'publication_year', 'journal_name', 'publisher_name', 'oa_status', 'fwci', 'cited_by_count']]

#q2_oa_clean
# Out:
#                                    id  \
# 0    https://openalex.org/W3197182136
# 1    https://openalex.org/W3097814634
# 2    https://openalex.org/W4311425960
# 3    https://openalex.org/W4220703584
# 4    https://openalex.org/W4210529131
# ..                                ...
# 193  https://openalex.org/W4285398133
# 194  https://openalex.org/W4393072836
# 195  https://openalex.org/W4391662786
# 196  https://openalex.org/W3114762970
# 197  https://openalex.org/W4309811892
#
#                                                doi  \
# 0         https://doi.org/10.1088/2631-8695/ac2353
# 1       https://doi.org/10.1038/s41598-020-75393-y
# 2      https://doi.org/10.1016/j.addma.2022.103357
# 3       https://doi.org/10.1016/j.isci.2022.104119
# 4       https://doi.org/10.1038/s41528-022-00139-x
# ..                                             ...
# 193  https://doi.org/10.1149/ma2022-01351418mtgabs
# 194             https://doi.org/10.1111/sjtg.12539
# 195  https://doi.org/10.1149/ma2023-02381818mtgabs
# 196  https://doi.org/10.1149/ma2020-02352257mtgabs
# 197  https://doi.org/10.1149/ma2022-02391413mtgabs
#
#                                                  title  publication_year  \
# 0    A review of primary technologies of thin-film ...              2021
# 1    Material properties and structure of natural g...              2020
# 2    Review of transfer learning in modeling additi...              2022
# 3    A 3D-printed neuromorphic humanoid hand for gr...              2022
# 4    3D printed leech-inspired origami dry electrod...              2022
# ..                                                 ...               ...
# 193  Fe- and Co-Containing Nitrogen-Doped Nanocarbo...              2022
# 194  Guest Editorial: The social life of Chinese in...              2024
# 195  Impact of Missing Cathode Catalyst Layer Areas...              2023
# 196  Exploring Component Interactions during Mechan...              2020
# 197  Visualization of Water Distribution in Fuel Ce...              2022
#
#                                 journal_name        publisher_name  oa_status  \
# 0               Engineering Research Express        IOP Publishing       True
# 1                         Scientific Reports      Nature Portfolio       True
# 2                     Additive Manufacturing           Elsevier BV      False
# 3                                   iScience            Cell Press       True
# 4                   npj Flexible Electronics      Nature Portfolio       True
# ..                                       ...                   ...        ...
# 193                    ECS Meeting Abstracts  Institute of Physics      False
# 194  Singapore Journal of Tropical Geography                 Wiley       True
# 195                    ECS Meeting Abstracts  Institute of Physics      False
# 196                    ECS Meeting Abstracts  Institute of Physics      False
# 197                    ECS Meeting Abstracts  Institute of Physics      False
#
#           fwci  cited_by_count
# 0     8.823900             124
# 1     2.559200              82
# 2     8.357900              67
# 3     2.653400              32
# 4     3.522300              44
# ..         ...             ...
# 193   0.000000               0
# 194  11.940961               3
# 195   0.000000               0
# 196   0.000000               0
# 197   0.000000               0
#
# [198 rows x 9 columns]

# %%
q2_oa_publisher_groups = pd.DataFrame(q2_oa_clean.groupby(['publisher_name']).count()['publication_year']).sort_values(by='publication_year', ascending=False).reset_index().rename(columns={'publication_year': 'publication_count'})
q2_oa_publisher_groups
# Out:
#                                        publisher_name  publication_count
# 0                                         Elsevier BV                 49
# 1                                Institute of Physics                 22
# 2                                               Wiley                 16
# 3                           American Chemical Society                 15
# 4                          Royal Society of Chemistry                  9
# 5      Multidisciplinary Digital Publishing Institute                  7
# 6                           American Physical Society                  7
# 7                                    Nature Portfolio                  7
# 8                                      IOP Publishing                  5
# 9                       American Institute of Physics                  5
# 10  Institute of Electrical and Electronics Engineers                  3
# 11                                    Frontiers Media                  3
# 12                                    SAGE Publishing                  3
# 13                    Springer Science+Business Media                  3
# 14                                    Springer Nature                  2
# 15                           RELX Group (Netherlands)                  2
# 16                                 Cornell University                  2
# 17                                   Taylor & Francis                  2
# 18  American Association for the Advancement of Sc...                  1
# 19                                  ASM International                  1
# 20           American Society of Mechanical Engineers                  1
# 21                                         Cell Press                  1
# 22                            Optica Publishing Group                  1
# 23                                 NRC Research Press                  1
# 24                                Pleiades Publishing                  1
# 25                            Oxford University Press                  1
# 26     Society for Industrial and Applied Mathematics                  1
# 27                                      Royal Society                  1

# %%
q2_oa_big_pub = q2_oa_publisher_groups[q2_oa_publisher_groups['publication_count']>3]
q2_oa_big_pub.head()
# Out:
#                publisher_name  publication_count
# 0                 Elsevier BV                 49
# 1        Institute of Physics                 22
# 2                       Wiley                 16
# 3   American Chemical Society                 15
# 4  Royal Society of Chemistry                  9

# %%
# Create the bar graph
plt.bar(q2_oa_big_pub['publisher_name'], q2_oa_big_pub['publication_count'])

# Add labels and a title
plt.xlabel("Publisher Name")
plt.ylabel("Publication Count")
plt.title("Query 2 OA publishers with >3 publications")
plt.xticks(range(len(q2_oa_big_pub['publisher_name'])), q2_oa_big_pub['publisher_name'], rotation='vertical') # or rotation=90

# Display the plot
plt.show()

# %% [markdown]
# ### SciVal

# %%
q2_sv_raw.columns
# Out:
# Index(['Authors', 'Author full names', 'Author(s) ID', 'Title', 'Year',
#        'Source title', 'Volume', 'Issue', 'Art. No.', 'Page start', 'Page end',
#        'Cited by', 'DOI', 'Link', 'Affiliations', 'Authors with affiliations',
#        'Correspondence Address', 'Editors', 'Publisher', 'ISSN', 'ISBN',
#        'CODEN', 'PubMed ID', 'Language of Original Document',
#        'Abbreviated Source Title', 'Document Type', 'Publication Stage',
#        'Open Access', 'Source', 'EID'],
#       dtype='object')

# %% [markdown]
# i want to keep id, doi, title, publication year, extract publisher name from primary location, extract is oa from open_access, ~~fwci~~, cited_by_count only

# %%
q2_sv_clean = q2_sv_raw.copy()
q2_sv_clean = q2_sv_clean[['EID', 'DOI', 'Title', 'Year', 'Publisher', 'Source title', 'Open Access', 'Cited by']]

#q2_sv_clean

# %%
q2_sv_publisher_groups = pd.DataFrame(q2_sv_clean.groupby(['Publisher']).count()['Year']).sort_values(by='Year', ascending=False).reset_index().rename(columns={'Year': 'publication_count'})
q2_sv_publisher_groups
# Out:
#                                             Publisher  publication_count
# 0                                        Elsevier Ltd                 41
# 1                                       Elsevier B.V.                 27
# 2                             John Wiley and Sons Inc                 24
# 3   Institute of Electrical and Electronics Engine...                 20
# 4                           American Chemical Society                 17
# ..                                                ...                ...
# 78                        University of Toronto Press                  1
# 79                                     VLDB Endowment                  1
# 80                                   Wiley-VCH Verlag                  1
# 81                 Wiley-VCH Verlag info@wiley-vch.de                  1
# 82                                              wiley                  1
#
# [83 rows x 2 columns]

# %%
q2_sv_big_pub = q2_sv_publisher_groups[q2_sv_publisher_groups['publication_count']>3]
#q2_oa_big_pub.head()

# Create the bar graph
plt.bar(q2_sv_big_pub['Publisher'], q2_sv_big_pub['publication_count'])

plt.xlabel("Publisher Name")
plt.ylabel("Publication Count")
plt.title("Query 2 SV publishers with >3 publications")
plt.xticks(range(len(q2_sv_big_pub['Publisher'])), q2_sv_big_pub['Publisher'], rotation='vertical') 

plt.show()

# %% [markdown]
# Again SV has more publishers, due to bad name standardization

# %% [markdown]
# ## Query 3

# %% [markdown]
# ### OpenAlex

# %% [markdown]
# i want to keep id, doi, title, publication year, extract publisher name from primary location, extract is oa from open_access, fwci, cited_by_count only

# %%
q3_oa_clean = q3_oa_raw.copy()
q3_oa_clean['publisher_TEMP'] = q3_oa_clean['primary_location'].apply(lambda x: ast.literal_eval(x))
q3_oa_clean['journal_name'] = q3_oa_clean['publisher_TEMP'].apply(lambda x: x['raw_source_name'])
q3_oa_clean['publisher_TEMP2'] = q3_oa_clean['publisher_TEMP'].apply(lambda x: x['source'])
q3_oa_clean['publisher_name'] = q3_oa_clean['publisher_TEMP2'].apply(lambda x: x['host_organization_name'] if x is not None else None)
q3_oa_clean['oa_TEMP'] = q3_oa_clean['open_access'].apply(lambda x: ast.literal_eval(x))
q3_oa_clean['oa_status'] = q3_oa_clean['oa_TEMP'].apply(lambda x: x['is_oa'])
q3_oa_clean = q3_oa_clean[['id', 'doi', 'title', 'publication_year', 'journal_name', 'publisher_name', 'oa_status', 'fwci', 'cited_by_count']]

#q3_oa_clean

# %%
q3_oa_publisher_groups = pd.DataFrame(q3_oa_clean.groupby(['publisher_name']).count()['publication_year']).sort_values(by='publication_year', ascending=False).reset_index().rename(columns={'publication_year': 'publication_count'})
q3_oa_publisher_groups
# Out:
#                       publisher_name  publication_count
# 0                        Elsevier BV                 73
# 1                   Taylor & Francis                 64
# 2                              Wiley                 48
# 3                    SAGE Publishing                 37
# 4               University of Oxford                 33
# ..                               ...                ...
# 90    University of California Press                  1
# 91            University of Winnipeg                  1
# 92       University of Toronto Press                  1
# 93                          Wellcome                  1
# 94  Wilfrid Laurier University Press                  1
#
# [95 rows x 2 columns]

# %%
q3_oa_big_pub = q3_oa_publisher_groups[q3_oa_publisher_groups['publication_count']>3]
q3_oa_big_pub.head()
# Out:
#          publisher_name  publication_count
# 0           Elsevier BV                 73
# 1      Taylor & Francis                 64
# 2                 Wiley                 48
# 3       SAGE Publishing                 37
# 4  University of Oxford                 33

# %%
# Create the bar graph
plt.bar(q3_oa_big_pub['publisher_name'], q3_oa_big_pub['publication_count'])

# Add labels and a title
plt.xlabel("Publisher Name")
plt.ylabel("Publication Count")
plt.title("Query 3 OA publishers with >3 publications")
plt.xticks(range(len(q3_oa_big_pub['publisher_name'])), q3_oa_big_pub['publisher_name'], rotation='vertical') # or rotation=90

# Display the plot
plt.show()

# %% [markdown]
# ### SciVal

# %%
q3_sv_raw.columns
# Out:
# Index(['Authors', 'Author full names', 'Author(s) ID', 'Title', 'Year',
#        'Source title', 'Volume', 'Issue', 'Art. No.', 'Page start', 'Page end',
#        'Cited by', 'DOI', 'Link', 'Affiliations', 'Authors with affiliations',
#        'Correspondence Address', 'Editors', 'Publisher', 'ISSN', 'ISBN',
#        'CODEN', 'PubMed ID', 'Language of Original Document',
#        'Abbreviated Source Title', 'Document Type', 'Publication Stage',
#        'Open Access', 'Source', 'EID'],
#       dtype='object')

# %% [markdown]
# i want to keep id, doi, title, publication year, extract publisher name from primary location, extract is oa from open_access, ~~fwci~~, cited_by_count only

# %%
q3_sv_clean = q3_sv_raw.copy()
q3_sv_clean = q3_sv_clean[['EID', 'DOI', 'Title', 'Year', 'Publisher', 'Source title', 'Open Access', 'Cited by']]

#q3_sv_clean

# %%
q3_sv_publisher_groups = pd.DataFrame(q3_sv_clean.groupby(['Publisher']).count()['Year']).sort_values(by='Year', ascending=False).reset_index().rename(columns={'Year': 'publication_count'})
q3_sv_publisher_groups
# Out:
#                      Publisher  publication_count
# 0                 Elsevier Ltd                 59
# 1                    Routledge                 56
# 2      John Wiley and Sons Inc                 37
# 3           BioMed Central Ltd                 33
# 4           Taylor and Francis                 30
# ..                         ...                ...
# 155                  Volcanica                  1
# 156  Weston Medical Publishing                  1
# 157    WellBeing International                  1
# 158     Walter de Gruyter GmbH                  1
# 159  World Health Organization                  1
#
# [160 rows x 2 columns]

# %%
q3_sv_big_pub = q3_sv_publisher_groups[q3_sv_publisher_groups['publication_count']>3]
#q3_sv_big_pub.head()

# Create the bar graph
plt.bar(q3_sv_big_pub['Publisher'], q3_sv_big_pub['publication_count'])

plt.xlabel("Publisher Name")
plt.ylabel("Publication Count")
plt.title("Query 3 SV publishers with >3 publications")
plt.xticks(range(len(q3_sv_big_pub['Publisher'])), q3_sv_big_pub['Publisher'], rotation='vertical') 

plt.show()

# %% [markdown]
# Again SV has more publishers, due to bad name standardization
