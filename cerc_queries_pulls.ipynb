# %%
# import necessary libraries
import requests
import json
import pandas as pd
import os

# %% [markdown]
# ## QUERY 1 - Defence & dual-use technologies

# %%
# initialize the API URL
# the cursor allows us to pull multiple pages of results to get all SFU works in one call. 
# NOTE: SFU's institutional id in OpenAlex is I18014f758

url_with_cursor = 'https://api.openalex.org/works?page=1&filter=publication_year:2020-2024,authorships.institutions.lineage:i18014758&search.title_and_abstract=%22defence+technolog*%22+OR+%22defense+technolog*%22+OR+%22dual-use+technolog*%22+OR+%22security+technolog*%22+OR+%22military+technolog*%22+OR+%22national+security%22+OR+%22security+innovation%22+OR+%22civil-military%22+OR+%22aerospace+system*%22+OR+%22aerospace+engineering%22+OR+%22space+system*%22+OR+%22space+situational+awareness%22+OR+%22space+domain+awareness%22+OR+%22autonomous+system*%22+OR+%22unmanned+system*%22+OR+%22uncrewed+system*%22+OR+%22robotic+system*%22+OR+%22swarm+robotic*%22+OR+%22surveillance+system*%22+OR+%22situational+awareness%22+OR+%22sensor+fusion%22+OR+%22remote+sensing%22+OR+%22radar+system*%22+OR+%22infrared+sensing%22+OR+%22hyperspectral+sensing%22+OR+%22sonar+system*%22+OR+%22electro-optical+system*%22+OR+%22secure+communication*%22+OR+%22tactical+communication*%22+OR+%22mission-critical+system*%22+OR+%22resilient+communication*%22+OR+%22navigation+resilience%22+OR+%22positioning+navigation+timing%22+OR+%22cyber+defence%22+OR+%22cybersecurity+for+critical+system*%22+OR+%22electronic+warfare%22+OR+%22electromagnetic+spectrum%22+OR+%22signals+intelligence%22+OR+%22information+operation*%22+OR+%22advanced+material*%22+OR+%22structural+material*%22+OR+%22lightweight+material*%22+OR+%22high-performance+material*%22+OR+%22ballistic+material*%22+OR+%22armour+material*%22+OR+%22blast-resistant+material*%22+OR+%22stealth+material*%22+OR+%22signature+management%22+OR+%22explosive+detection%22+OR+%22hazard+detection%22+OR+%22chemical+threat+detection%22+OR+%22biological+threat+detection%22+OR+%22radiological+threat+detection%22+OR+%22threat+detection+model*%22+OR+%22simulation%22+OR+%22wargaming%22+OR+%22operational+analys*%22+OR+%22decision+support+system*%22+OR+%22mission+planning%22+OR+%22human+systems+integration%22+OR+%22human+performance%22+OR+%22hypersonic+system*%22+OR+%22advanced+propulsion%22+OR+%22rocket+propulsion%22+OR+%22arms+control%22+OR+%22export+control%22+OR+%22dual-use+research+governance%22+OR+%22ethic*+of+autonomous+system*%22+OR+%22human+control+over+autonomous+system*%22+OR+%22civil+protection%22+OR+%22emergency+response+system*%22&sort=relevance_score:desc&cursor={}'
cursor = '*'

# empty containter to store the results
full_results_1 = []

# loop through pages
while cursor:
    
    # set cursor value and request page from OpenAlex
    url = url_with_cursor.format(cursor)
    
    #print("\n" + url)
    page_with_results = requests.get(url)
    page_with_results = page_with_results.json()
    
    # loop through partial list of results
    results = page_with_results['results']
    
    full_results_1 += results

    # update cursor to meta.next_cursor
    cursor = page_with_results['meta']['next_cursor']
    #print("next cursor is: ", cursor)

# %% [markdown]
# ## QUERY 2 - Manufacturing & Advanced Materials

# %%
# initialize the API URL
# the cursor allows us to pull multiple pages of results to get all SFU works in one call. 
# NOTE: SFU's institutional id in OpenAlex is I18014f758

url_with_cursor = 'https://api.openalex.org/works?page=1&filter=publication_year:2020-2024,authorships.institutions.lineage:i18014758&sort=relevance_score:desc&search.title_and_abstract=%22manufactur*%22+OR%22advanced+manufactur*%22+OR%22manufacturing+system*%22+OR%22manufacturing+process*%22+OR%22manufacturing+technolog*%22+OR%22manufacturing+engineering%22+OR%22smart+manufactur*%22+OR%22digital+manufactur*%22+OR%22intelligent+manufactur*%22+OR%22cyber-physical+production+system*%22+OR%22industrial+automation%22+OR%22manufactur*+automation%22+OR%22industrial+robotic*%22+OR%22robot-assisted+manufactur*%22+OR%22machine+vision+for+manufactur*%22+OR%22quality+inspection+in+manufactur*%22+OR%22predictive+maintenance%22+OR%22additive+manufactur*%22+OR%223D+print*%22+OR%22metal+additive+manufactur*%22+OR%22polymer+additive+manufactur*%22+OR%22powder+bed+fusion%22+OR%22direct+energy+deposition%22+OR%22precision+machin*%22+OR%22ultra-precision+manufactur*%22+OR%22material*+scienc*%22+OR%22advanced+material*%22+OR%22functional+material*%22+OR%22structural+material*%22+OR%22engineering+material*%22+OR%22material*+design%22+OR%22material*+processing%22+OR%22material*+synthesis%22+OR%22material*+characterization%22+OR%22material*+performance%22+OR%22material*+property*%22+OR%22material*+mechanic*%22+OR%22composite+material*%22+OR%22fiber-reinforced+composite*%22+OR%22lightweight+material*%22+OR%22high-performance+material*%22+OR%22high-entropy+alloy*%22+OR%22metal+alloy*%22+OR%22aluminium+alloy*%22+OR%22magnesium+alloy*%22+OR%22superalloy*%22+OR%22corrosion-resistant+material*%22+OR%22nanomaterial*%22+OR%22nanostructured+material*%22+OR%22thin+film*%22+OR%22coating+technolog*%22+OR%22surface+engineering%22+OR%22laser+surface+processing%22+OR%22plasma+surface+treatment%22+OR%22microfabrication%22+OR%22nanofabrication%22+OR%22semiconductor+processing%22+OR%22thin+film+deposition%22+OR%22fracture+mechanic*%22+OR%22fatigue+behavior%22+OR%22fatigue+life%22+OR%22damage+mechanism*%22+OR%22failure+analysis%22+OR%22material*+informatic*%22+OR%22computational+material*%22+OR%22multi-scale+modell*%22+OR%22integrated+computational+material*+engineering%22+OR%22sustainable+manufactur*%22+OR%22resource-efficient+manufactur*%22+OR%22remanufactur*%22+OR%22closed-loop+manufactur*%22+OR%22design+for+manufacturability%22+OR%22design+for+disassembly%22&sort=relevance_score:desc&cursor={}'
cursor = '*'


# empty containter to store the results
full_results_2 = []

# loop through pages
while cursor:
    
    # set cursor value and request page from OpenAlex
    url = url_with_cursor.format(cursor)
    
    #print("\n" + url)
    page_with_results = requests.get(url)
    page_with_results = page_with_results.json()
    
    # loop through partial list of results
    results = page_with_results['results']
    
    full_results_2 += results

    # update cursor to meta.next_cursor
    cursor = page_with_results['meta']['next_cursor']
    #print("next cursor is: ", cursor)

# %% [markdown]
# ## QUERY 3 - Democratic & Community Resilience

# %%
# initialize the API URL
# the cursor allows us to pull multiple pages of results to get all SFU works in one call. 
# NOTE: SFU's institutional id in OpenAlex is I18014f758

url_with_cursor = 'https://api.openalex.org/works?page=1&filter=publication_year:2020-2024,authorships.institutions.lineage:i18014758&sort=relevance_score:desc&search.title_and_abstract=%22democracy%22+OR%22democratic+governance%22+OR%22democratic+institution*%22+OR%22democratic+process*%22+OR%22democratic+backsliding%22+OR%22democratic+quality%22+OR%22democratic+resilien*%22+OR%22civic+engagement%22+OR%22civic+participation%22+OR%22political+participation%22+OR%22deliberative+democracy%22+OR%22participatory+governance%22+OR%22public+participation%22+OR%22citizen+engagement%22+OR%22community+resilien*%22+OR%22social+resilien*%22+OR%22social+cohesion%22+OR%22social+capital%22+OR%22community+capacity%22+OR%22collective+action%22+OR%22collective+efficacy%22+OR%22community+development%22+OR%22place-based+development%22+OR%22local+communit*%22+OR%22neighbourhood*%22+OR%22public+trust%22+OR%22political+trust%22+OR%22institutional+trust%22+OR%22trust+in+institution*%22+OR%22legitimacy%22+OR%22governance+legitimacy%22+OR%22governance%22+OR%22public+governance%22+OR%22institutional+capacity%22+OR%22policy+capacity%22+OR%22public+administration%22+OR%22state+capacity%22+OR%22multi-level+governance%22+OR%22urban+governance%22+OR%22local+governance%22+OR%22institutional+resilien*%22+OR%22policy+resilien*%22+OR%22adaptive+governance%22+OR%22crisis+governance%22+OR%22misinformation%22+OR%22disinformation%22+OR%22media+literacy%22+OR%22political+communication%22+OR%22digital+civic+engagement%22+OR%22human+rights%22+OR%22minority+rights%22+OR%22indigenous+governance%22+OR%22access+to+justice%22+OR%22restorative+justice%22+OR%22peacebuilding%22+OR%22social+inequality%22+OR%22spatial+inequality%22+OR%22housing+insecurity%22+OR%22homelessness%22+OR%22migration+polic*%22+OR%22integration+polic*%22+OR%22inclusive+governance%22+OR%22anti-racist+polic*%22+OR%22public+opinion%22+OR%22public+consultation%22+OR%22community-based+participatory+research%22+OR%22participatory+action+research%22&sort=relevance_score:desc&cursor={}'
cursor = '*'

# empty containter to store the results
full_results_3 = []

# loop through pages
while cursor:
    
    # set cursor value and request page from OpenAlex
    url = url_with_cursor.format(cursor)
    
    #print("\n" + url)
    page_with_results = requests.get(url)
    page_with_results = page_with_results.json()
    
    # loop through partial list of results
    results = page_with_results['results']
    
    full_results_3 += results

    # update cursor to meta.next_cursor
    cursor = page_with_results['meta']['next_cursor']
    #print("next cursor is: ", cursor)

# %% [markdown]
# ## 2024 High Impact Pubs

# %%
# initialize the API URL
# the cursor allows us to pull multiple pages of results to get all SFU works in one call. 
# NOTE: SFU's institutional id in OpenAlex is I18014f758

url_with_cursor = 'https://api.openalex.org/works?page=1&filter=publication_year:2024,authorships.institutions.lineage:i18014758&cursor={}'
cursor = '*'

# empty containter to store the results
full_results_4 = []

# loop through pages
while cursor:
    
    # set cursor value and request page from OpenAlex
    url = url_with_cursor.format(cursor)
    
    #print("\n" + url)
    page_with_results = requests.get(url)
    page_with_results = page_with_results.json()
    
    # loop through partial list of results
    results = page_with_results['results']
    
    full_results_4 += results

    # update cursor to meta.next_cursor
    cursor = page_with_results['meta']['next_cursor']
    #print("next cursor is: ", cursor)

# %% [markdown]
# ## SAVE ALL

# %%
pd.DataFrame(full_results_1).to_csv('./cerc_results/query1.csv', index = False)
pd.DataFrame(full_results_2).to_csv('./cerc_results/query2.csv', index = False)
pd.DataFrame(full_results_3).to_csv('./cerc_results/query3.csv', index = False)

# %%
pd.DataFrame(full_results_4).to_csv('./cerc_results/works2024.csv', index = False)
